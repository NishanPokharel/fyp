# %%
import numpy as np
import pandas as pd
import seaborn as sns
import os
from matplotlib import pyplot as plt

# %%
missing_value = ["N/a", "na", np.nan]
df = pd.read_csv("./Dataset/tweets_24_tendencias_raw.csv", low_memory=False, na_values=missing_value)

# %%
df.head()
# Out:
#    Unnamed: 0.1            id  conversation_id  \
# 0             0  1.231919e+18     1.231919e+18
# 1             1  1.231871e+18     1.231871e+18
# 2             2  1.232062e+18     1.162480e+18
# 3             3  1.232044e+18     1.232044e+18
# 4             4  1.232044e+18     1.232044e+18
#
#                                   created_at        date      time  timezone  \
# 0  2020-02-24 13:28:15 Romance Standard Time  2020-02-24  13:28:15     100.0
# 1  2020-02-24 10:18:31 Romance Standard Time  2020-02-24  10:18:31     100.0
# 2  2020-02-24 22:56:17 Romance Standard Time  2020-02-24  22:56:17     100.0
# 3  2020-02-24 21:46:20 Romance Standard Time  2020-02-24  21:46:20     100.0
# 4  2020-02-24 21:45:00 Romance Standard Time  2020-02-24  21:45:00     100.0
#
#         user_id         username                 name  ... reply_to  \
# 0  5.487197e+08         djurekbl         Marko Djurek  ...       []
# 1  7.882786e+17  indioscaledonia  Indios de Caledonia  ...       []
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0.1             0
# id                  901218
# conversation_id     901218
# created_at          901218
# date                     0
# time                     0
# timezone            901218
# user_id             901218
# username                 0
# name                901260
# place              1616032
# tweet                  219
# language            901218
# mentions            805896
# urls                     0
# photos                   0
# replies_count            0
# retweets_count           0
# likes_count              0
# hashtags            773328
# cashtags            901218
# link                901218
# retweet                  0
# quote_url          1564275
# video                    0
# thumbnail          1477745
# near               1618956
# geo                1618956
# source             1618956
# user_rt_id         1618956
# user_rt            1618956
# retweet_id         1618956
# reply_to            522006
# retweet_date       1618956
# ...

# %%
df
# Out:
#          Unnamed: 0.1            id  conversation_id  \
# 0                   0  1.231919e+18     1.231919e+18
# 1                   1  1.231871e+18     1.231871e+18
# 2                   2  1.232062e+18     1.162480e+18
# 3                   3  1.232044e+18     1.232044e+18
# 4                   4  1.232044e+18     1.232044e+18
# ...               ...           ...              ...
# 1618951        300210  1.231731e+18     1.231731e+18
# 1618952        300211  1.231730e+18     1.231730e+18
# 1618953        300212  1.231730e+18     1.231730e+18
# 1618954        300213  1.231730e+18     1.231610e+18
# 1618955        300214  1.231730e+18     1.231730e+18
#
#                                         created_at        date      time  \
# 0        2020-02-24 13:28:15 Romance Standard Time  2020-02-24  13:28:15
# 1        2020-02-24 10:18:31 Romance Standard Time  2020-02-24  10:18:31
# 2        2020-02-24 22:56:17 Romance Standard Time  2020-02-24  22:56:17
# ...

# %%
df.dropna(how="all")
# df.dropna()
# Out:
#          Unnamed: 0.1            id  conversation_id  \
# 0                   0  1.231919e+18     1.231919e+18
# 1                   1  1.231871e+18     1.231871e+18
# 2                   2  1.232062e+18     1.162480e+18
# 3                   3  1.232044e+18     1.232044e+18
# 4                   4  1.232044e+18     1.232044e+18
# ...               ...           ...              ...
# 1618951        300210  1.231731e+18     1.231731e+18
# 1618952        300211  1.231730e+18     1.231730e+18
# 1618953        300212  1.231730e+18     1.231730e+18
# 1618954        300213  1.231730e+18     1.231610e+18
# 1618955        300214  1.231730e+18     1.231730e+18
#
#                                         created_at        date      time  \
# 0        2020-02-24 13:28:15 Romance Standard Time  2020-02-24  13:28:15
# 1        2020-02-24 10:18:31 Romance Standard Time  2020-02-24  10:18:31
# 2        2020-02-24 22:56:17 Romance Standard Time  2020-02-24  22:56:17
# ...
